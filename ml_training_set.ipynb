# %%
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

import src.dino as dino
# from src import plotting

DOWNSAMPLE_RATIO = 4

def get_value_below(df, value):
    df_with_value = df.where(df==value).dropna(how="all").dropna(axis=1)
    row = df_with_value.index[0]
    column = df_with_value.columns[0]
    return df[column][row+1]


# Generate brightness response images for all inputs
data_dir = Path("training")
for file in tqdm(list((data_dir / "images").iterdir()), desc="generating training set"):
    if not file.suffix in [".exr", ".hdr"]:
        print(f"{file} is not an HDR image, skipping...")
        continue
    export_path = str(data_dir / "brightnesses" / file.stem) + ".npy"
    if Path(export_path).exists():
        print(f"{export_path} already exists")
        brightness = np.load(export_path)
        print(brightness.shape)
        continue
    data_file = str(data_dir / "image_data" / file.stem) + "Data.xls"
    data_pd = pd.read_excel(data_file)
    stated_dyn_range = get_value_below(data_pd, "Dyn. Range")
    max_L = get_value_below(data_pd, "Max.")
    min_L = get_value_below(data_pd, "Min.")
    mean_L = float(get_value_below(data_pd, "Mean"))
    image = dino.read_image(str(file))
    image = dino.resize_image(image, resize_width=round(image.shape[1]/DOWNSAMPLE_RATIO))
    L = dino.fairchild_to_relative_luminance(image)
    # Scale to stated luminance range
    L = (L / np.mean(L)) * mean_L
    actual_dyn_range = round(np.max(L) / np.min(L)) if np.min(L) > 0 else "inf"
    print(f"Stated vs actual dynamic range: {stated_dyn_range} vs {actual_dyn_range} (max: {round(np.max(L))}, min: {round(np.min(L), 1)})")
    print(f"Stated vs actual mean luminance: {mean_L} vs {round(np.mean(L), 1)}")
    brightness = dino.dn_brightness_model(L)
    # L = torch.Tensor(L).to("cuda")
    # brightness = dino.pytorch.dn_brightness_model(L)
    # brightness = brightness.detach().cpu().to_numpy()
    print(brightness.shape)
    print(f"Exporting {export_path}")
    np.save(export_path, brightness)
    # Visualize brightness response
    # plotting.image_pseudocolor_plot(brightness, title=file.stem, cmap="Grays_r", display=True)
# Out:
# generating training set:   0%|          | 0/27 [00:00<?, ?it/s]
# Stated vs actual dynamic range: 0.3K:1 vs 5524 (max: 18067, min: 3.299999952316284)
# Stated vs actual mean luminance: 1430.0 vs 1430.0
# (712, 1071)
# Exporting training/brightnesses/MirrorLake.npy
# Stated vs actual dynamic range: 0.3K:1 vs 245 (max: 8940, min: 36.5)
# Stated vs actual mean luminance: 2570.0 vs 2570.0
# (712, 1072)
# Exporting training/brightnesses/TupperLake(1).npy
# Stated vs actual dynamic range: 3.3K:1 vs 18263 (max: 122299, min: 6.699999809265137)
# Stated vs actual mean luminance: 2320.0 vs 2320.0
# (712, 1072)
# Exporting training/brightnesses/MasonLake(2).npy
# Stated vs actual dynamic range: 25K:1 vs 36036 (max: 348529, min: 9.699999809265137)
# Stated vs actual mean luminance: 5730.0 vs 5730.0
# (603, 1072)
# Exporting training/brightnesses/MammothHotSprings.npy
# Stated vs actual dynamic range: 15.5K:1 vs 176724 (max: 466585, min: 2.5999999046325684)
# Stated vs actual mean luminance: 10500.0 vs 10500.0
# (712, 1072)
# Exporting training/brightnesses/DevilsTower.npy
# Stated vs actual dynamic range: 13K:1 vs 12869 (max: 240653, min: 18.700000762939453)
# Stated vs actual mean luminance: 3940.0 vs 3940.0
# (603, 1072)
# Exporting training/brightnesses/BenJerrys.npy
# Stated vs actual dynamic range: 20.9K:1 vs 91869 (max: 27977, min: 0.30000001192092896)
# Stated vs actual mean luminance: 675.0 vs 675.0
# (1072, 712)
# Exporting training/brightnesses/YosemiteFalls.npy
# Stated vs actual dynamic range: 0.5K:1 vs 2940 (max: 3064, min: 1.0)
# Stated vs actual mean luminance: 709.0 vs 709.0
# (603, 1072)
# Exporting training/brightnesses/NorthBubble.npy
# Stated vs actual dynamic range: 1.2K:1 vs 8453 (max: 3285, min: 0.4000000059604645)
# Stated vs actual mean luminance: 333.0 vs 333.0
# (603, 1072)
# Exporting training/brightnesses/PaulBunyan.npy
# Stated vs actual dynamic range: 2.9K:1 vs 23459 (max: 26184, min: 1.100000023841858)
# Stated vs actual mean luminance: 302.0 vs 302.0
# (603, 1072)
# Exporting training/brightnesses/BarHarborPresunrise.npy
# Stated vs actual dynamic range: 3.1K:1 vs 12661 (max: 37660, min: 3.0)
# Stated vs actual mean luminance: 4770.0 vs 4770.0
# (670, 1072)
# Exporting training/brightnesses/RITTiger.npy
# Stated vs actual dynamic range: 4.7K:1 vs 43655 (max: 208904, min: 4.800000190734863)
# Stated vs actual mean luminance: 6580.0 vs 6580.0
# (712, 1072)
# Exporting training/brightnesses/OtterPoint.npy
# Stated vs actual dynamic range: 36K:1 vs 60567 (max: 114598, min: 1.899999976158142)
# Stated vs actual mean luminance: 4150.0 vs 4150.0
# (603, 1072)
# Exporting training/brightnesses/DevilsBathtub.npy
# Stated vs actual dynamic range: 2.9K:1 vs 594 (max: 28435, min: 47.900001525878906)
# Stated vs actual mean luminance: 4800.0 vs 4800.0
# (603, 1072)
# Exporting training/brightnesses/MackinacBridge.npy
# Stated vs actual dynamic range: 3.2K:1 vs 10598 (max: 12396, min: 1.2000000476837158)
# Stated vs actual mean luminance: 2280.0 vs 2280.0
# (603, 1072)
# Exporting training/brightnesses/RoundStoneBarn.npy
# Stated vs actual dynamic range: 4.5K:1 vs 18159 (max: 29122, min: 1.600000023841858)
# Stated vs actual mean luminance: 3390.0 vs 3390.0
# (588, 1046)
# Exporting training/brightnesses/PeckLake.npy
# Stated vs actual dynamic range: 48K:1 vs 89271 (max: 68869, min: 0.800000011920929)
# Stated vs actual mean luminance: 302.0 vs 302.0
# (603, 1072)
# Exporting training/brightnesses/BarHarborSunrise.npy
# Stated vs actual dynamic range: 0.866K:1 vs 3375 (max: 4045, min: 1.2000000476837158)
# Stated vs actual mean luminance: 540.0 vs 540.0
# (603, 1072)
# Exporting training/brightnesses/TaughannockFalls.npy
# Stated vs actual dynamic range: 800K:1 vs 1138293 (max: 13790, min: 0.0)
# Stated vs actual mean luminance: 42.2 vs 42.20000076293945
# (438, 779)
# Exporting training/brightnesses/LuxoDoubleChecker.npy
# Stated vs actual dynamic range: 1.1K:1 vs 66621 (max: 5781, min: 0.10000000149011612)
# Stated vs actual mean luminance: 226.0 vs 226.0
# (1072, 712)
# Exporting training/brightnesses/GeneralGrant.npy
# Stated vs actual dynamic range: 2.6K:1 vs 3641 (max: 36240, min: 10.0)
# Stated vs actual mean luminance: 2628.0 vs 2628.0
# (712, 1072)
# Exporting training/brightnesses/TheGrotto.npy
# Stated vs actual dynamic range: 0.2K:1 vs 763 (max: 23819, min: 31.200000762939453)
# Stated vs actual mean luminance: 7170.0 vs 7170.0
# (670, 1072)
# Exporting training/brightnesses/DelicateArch.npy
# Stated vs actual dynamic range: 42K:1 vs 214618 (max: 17301, min: 0.10000000149011612)
# Stated vs actual mean luminance: 147.0 vs 147.0
# (1072, 712)
# Exporting training/brightnesses/LadyBirdRedwoods.npy
# Stated vs actual dynamic range: 500K:1 vs 3700 (max: 15029, min: 4.099999904632568)
# Stated vs actual mean luminance: 2020.0 vs 2020.0
# (712, 1072)
# Exporting training/brightnesses/BloomingGorse(2).npy
# Stated vs actual dynamic range: 14K:1 vs 91249 (max: 8422, min: 0.10000000149011612)
# Stated vs actual mean luminance: 132.0 vs 132.0
# (603, 1072)
# Exporting training/brightnesses/AmikeusBeaverDamPM1.npy
# Stated vs actual dynamic range: 13K:1 vs 19648 (max: 4369, min: 0.20000000298023224)
# Stated vs actual mean luminance: 303.0 vs 303.0
# (712, 1072)
# Exporting training/brightnesses/507.npy
# Stated vs actual dynamic range: .187K:1 vs 653 (max: 32618, min: 50.0)
# Stated vs actual mean luminance: 7120.0 vs 7120.0
# (602, 1070)
# Exporting training/brightnesses/NiagaraFalls.npy
